# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
yrbss = pd.read_csv('../data/yrbss_2017.csv')

# %%
us = yrbss[yrbss['LocationAbbr'] == 'XX']

# %%
uiv = us[us['Topic'] == 'Unintentional Injuries and Violence']

# %%
bcv = uiv[uiv['Subtopic'] == 'Behaviors that Contribute to Violence']

# %%
web = bcv[bcv['Greater_Risk_Question'] == 'Were electronically bullied']

# %%
web['Lesser_Risk_Question'].value_counts()
# Out:
# Were not electronically bullied    1320
# Name: Lesser_Risk_Question, dtype: int64

# %%
web.head()
# Out:
#        YEAR LocationAbbr   LocationDesc DataSource  \
# 26214  2017           XX  United States      YRBSS
# 42947  2017           XX  United States      YRBSS
# 44230  2017           XX  United States      YRBSS
# 45949  2017           XX  United States      YRBSS
# 47207  2017           XX  United States      YRBSS
#
#                                      Topic  \
# 26214  Unintentional Injuries and Violence
# 42947  Unintentional Injuries and Violence
# 44230  Unintentional Injuries and Violence
# 45949  Unintentional Injuries and Violence
# 47207  Unintentional Injuries and Violence
#
#                                     Subtopic    ShortQuestionText  \
# 26214  Behaviors that Contribute to Violence  Electronic bullying
# 42947  Behaviors that Contribute to Violence  Electronic bullying
# 44230  Behaviors that Contribute to Violence  Electronic bullying
# 45949  Behaviors that Contribute to Violence  Electronic bullying
# ...

# %%
count = us[(us['Grade'] == 'Total') & (us['Sex'] == 'Total') &
        (us['Race'] == 'Asian') & (us['SexualIdentity'] == 'Total') & (us['SexOfSexualContacts'] == 'Total')]

# %%
count.head()
# Out:
#         YEAR LocationAbbr   LocationDesc DataSource  \
# 25361   2017           XX  United States      YRBSS
# 64645   2017           XX  United States      YRBSS
# 139722  2017           XX  United States      YRBSS
# 208112  2017           XX  United States      YRBSS
# 232087  2017           XX  United States      YRBSS
#
#                                       Topic                   Subtopic  \
# 25361                           Tobacco Use          Other Tobacco Use
# 64645                     Dietary Behaviors              Sports Drinks
# 139722                    Dietary Behaviors                Soda or pop
# 208112                    Physical Activity          Physical Activity
# 232087  Unintentional Injuries and Violence  Suicide-Related Behaviors
#
#                           ShortQuestionText  \
# 25361   Current daily smokeless tobacco use
# 64645                      No sports drinks
# 139722                     No soda drinking
# ...

# %%
uiv[(uiv['Subtopic'] == 'Behaviors that Contribute to Violence') & (uiv['Grade'] == 'Total') & (uiv['Sex'] == 'Total') &
        (uiv['Race'] == 'Asian') & (uiv['SexualIdentity'] == 'Total') & (uiv['SexOfSexualContacts'] == 'Total')]
# Out:
#          YEAR LocationAbbr   LocationDesc DataSource  \
# 1431495  2017           XX  United States      YRBSS
# 1672804  2017           XX  United States      YRBSS
# 2686442  2017           XX  United States      YRBSS
# 2877133  2017           XX  United States      YRBSS
# 3529956  2017           XX  United States      YRBSS
# 4486483  2017           XX  United States      YRBSS
# 4939680  2017           XX  United States      YRBSS
# 6000753  2017           XX  United States      YRBSS
# 7027185  2017           XX  United States      YRBSS
# 7067772  2017           XX  United States      YRBSS
# 7095592  2017           XX  United States      YRBSS
# 7177515  2017           XX  United States      YRBSS
# 7246191  2017           XX  United States      YRBSS
#
#                                        Topic  \
# 1431495  Unintentional Injuries and Violence
# 1672804  Unintentional Injuries and Violence
# 2686442  Unintentional Injuries and Violence
# ...
