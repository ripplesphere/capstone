# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline  

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
yrbss = pd.read_csv('../data/yrbss_2017.csv')

# %%
yrbss.shape
# Out:
# (7461960, 40)

# %%
yrbss.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Topic',
#        'Subtopic', 'ShortQuestionText', 'Greater_Risk_Question', 'Description',
#        'Data_Value_Symbol', 'Data_Value_Type', 'Greater_Risk_Data_Value',
#        'Greater_Risk_Data_Value_Footnote_Symbol',
#        'Greater_Risk_Data_Value_Footnote', 'Greater_Risk_Low_Confidence_Limit',
#        'Greater_Risk_High_Confidence_Limit', 'Lesser_Risk_Question',
#        'Lesser_Risk_Data_Value', 'Lesser_Risk_Data_Value_Footnote_Symbol',
#        'Lesser_Risk_Data_Value_Footnote', 'Lesser_Risk_Low_Confidence_Limit',
#        'Lesser_Risk_High_Confidence_Limit', 'Sample_Size', 'Sex', 'Race',
#        'Grade', 'SexualIdentity', 'SexOfSexualContacts', 'GeoLocation',
#        'TopicId', 'SubTopicID', 'QuestionCode', 'LocationId', 'StratID1',
#        'StratID2', 'StratID3', 'StratID4', 'StratID5', 'StratificationType',
#        'StratID6'],
#       dtype='object')

# %%
yrbss.head(3)

# %%
yrbss[(yrbss['LocationId'] == 37.0) & (yrbss['Sex'] == "Female") & (yrbss['Race'] == "White") & (yrbss['Grade'] == "11th")]

# %%
yrbss['Topic'].value_counts()
# Out:
# Unintentional Injuries and Violence        1507200
# Tobacco Use                                1393080
# Dietary Behaviors                          1228560
# Alcohol and Other Drug Use                 1216320
# Sexual Behaviors                            949560
# Physical Activity                           617040
# Other Health Topics                         278160
# Obesity, Overweight, and Weight Control     272040
# Name: Topic, dtype: int64

# %%
uiv = yrbss[yrbss['Topic'] == 'Unintentional Injuries and Violence']

# %%
uiv['Subtopic'].value_counts()
# Out:
# Behaviors that Contribute to Violence                  887400
# Suicide-Related Behaviors                              364080
# Behaviors that Contribute to Unintentional Injuries    255720
# Name: Subtopic, dtype: int64

# %%
bcv = uiv[yrbss['Subtopic'] == 'Behaviors that Contribute to Violence']
# Out:
# <ipython-input-15-35ced2f43c0a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bcv = uiv[yrbss['Subtopic'] == 'Behaviors that Contribute to Violence']

# %%
bcv['Greater_Risk_Question'].value_counts()
# Out:
# Were electronically bullied                                                                  77880
# Were bullied on school property                                                              76560
# Experienced physical dating violence                                                         76320
# Did not go to school because they felt unsafe at school or on their way to or from school    73800
# Were in a physical fight                                                                     73800
# Were threatened or injured with a weapon on school property                                  72960
# Carried a weapon on school property                                                          71040
# Were ever physically forced to have sexual intercourse                                       67560
# Experienced sexual dating violence                                                           67200
# ...

# %%
web = bcv[yrbss['Greater_Risk_Question'] == 'Were electronically bullied']
# Out:
# <ipython-input-18-dc0039c70b60>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   web = bcv[yrbss['Greater_Risk_Question'] == 'Were electronically bullied']

# %%
web['Lesser_Risk_Question'].value_counts()
# Out:
# Were not electronically bullied    77880
# Name: Lesser_Risk_Question, dtype: int64

# %%
web['LocationAbbr'].value_counts()
# Out:
# SC     1320
# HO     1320
# CT     1320
# NYK    1320
# PA     1320
# AR     1320
# NE     1320
# NYJ    1320
# NC     1320
# XX     1320
# OK     1320
# NYC    1320
# SA     1320
# NH     1320
# IA     1320
# NYI    1320
# KY     1320
# NY     1320
# NM     1320
# PH     1320
# WV     1320
# CH     1320
# NV     1320
# RI     1320
# DE     1320
# OL     1320
# NYG    1320
# OA     1320
# ME     1320
# DCB    1320
# DKC    1320
# MI     1320
# GU     1320
# FL     1320
# FT     1320
# DU     1320
# BA     1320
# MM     1320
# PR     1320
# PB     1320
# MA     1320
# BO     1320
# CE     1320
# NYH    1320
# HI     1320
# TX     1320
# DT     1320
# FW     1320
# MP     1320
# WI     1320
# VT     1320
# CA     1320
# IL     1320
# ST     1320
# SF     1320
# LO     1320
# CO      720
# ND      720
# MD      720
# AZB     720
# MO      120
# UT      120
# MT      120
# ID      120
# KS      120
# LA      120
# TN      120
# AK      120
# VA      120
# ...

# %%
web[yrbss['LocationAbbr'] == 'XX']
# Out:
# <ipython-input-24-a466cc1cf7ec>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   web[yrbss['LocationAbbr'] == 'XX']
#          YEAR LocationAbbr   LocationDesc DataSource  \
# 26214    2017           XX  United States      YRBSS
# 42947    2017           XX  United States      YRBSS
# 44230    2017           XX  United States      YRBSS
# 45949    2017           XX  United States      YRBSS
# 47207    2017           XX  United States      YRBSS
# 49457    2017           XX  United States      YRBSS
# 51433    2017           XX  United States      YRBSS
# 60203    2017           XX  United States      YRBSS
# 61412    2017           XX  United States      YRBSS
# 64605    2017           XX  United States      YRBSS
# 65974    2017           XX  United States      YRBSS
# 70261    2017           XX  United States      YRBSS
# 70297    2017           XX  United States      YRBSS
# 71658    2017           XX  United States      YRBSS
# ...
