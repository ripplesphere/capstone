# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#this is a python magic function to automatically show matplotlib plots
# %matplotlib inline

# %%
yrbss = pd.read_csv('../data/yrbss_2017.csv')

# %%
yrbss.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Topic',
#        'Subtopic', 'ShortQuestionText', 'Greater_Risk_Question', 'Description',
#        'Data_Value_Symbol', 'Data_Value_Type', 'Greater_Risk_Data_Value',
#        'Greater_Risk_Data_Value_Footnote_Symbol',
#        'Greater_Risk_Data_Value_Footnote', 'Greater_Risk_Low_Confidence_Limit',
#        'Greater_Risk_High_Confidence_Limit', 'Lesser_Risk_Question',
#        'Lesser_Risk_Data_Value', 'Lesser_Risk_Data_Value_Footnote_Symbol',
#        'Lesser_Risk_Data_Value_Footnote', 'Lesser_Risk_Low_Confidence_Limit',
#        'Lesser_Risk_High_Confidence_Limit', 'Sample_Size', 'Sex', 'Race',
#        'Grade', 'SexualIdentity', 'SexOfSexualContacts', 'GeoLocation',
#        'TopicId', 'SubTopicID', 'QuestionCode', 'LocationId', 'StratID1',
#        'StratID2', 'StratID3', 'StratID4', 'StratID5', 'StratificationType',
#        'StratID6'],
#       dtype='object')

# %%
yrbss.head(3)[['LocationAbbr', 'Topic',
       'Subtopic', 'ShortQuestionText', 'Greater_Risk_Question', 'Description',
       'Greater_Risk_Data_Value',
       'Greater_Risk_Low_Confidence_Limit',
       'Greater_Risk_High_Confidence_Limit', 'Lesser_Risk_Question',
       'Lesser_Risk_Data_Value', 'Lesser_Risk_Data_Value_Footnote_Symbol',
       'Lesser_Risk_Data_Value_Footnote', 'Lesser_Risk_Low_Confidence_Limit',
       'Lesser_Risk_High_Confidence_Limit', 'Sample_Size', 'Sex', 'Race',
       'Grade', 'SexualIdentity', 'SexOfSexualContacts', 'GeoLocation',
       'LocationId']]
# Out:
#   LocationAbbr              Topic          Subtopic        ShortQuestionText  \
# 0           NC  Dietary Behaviors         Breakfast   Daily breakfast eating
# 1           PR  Dietary Behaviors         Breakfast         Breakfast eating
# 2           FL   Sexual Behaviors  Sexual Behaviors  Ever sexual intercourse
#
#                  Greater_Risk_Question                          Description  \
# 0  Did not eat breakfast on all 7 days  during the 7 days before the survey
# 1                Did not eat breakfast  during the 7 days before the survey
# 2          Ever had sexual intercourse                                  NaN
#
#    Greater_Risk_Data_Value  Greater_Risk_Low_Confidence_Limit  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                  37.5545                            25.0422
#
#    Greater_Risk_High_Confidence_Limit               Lesser_Risk_Question  ...  \
# 0                                 NaN        Ate breakfast on all 7 days  ...
# 1                                 NaN  Ate breakfast on one or more days  ...
# 2                              51.983       Never had sexual intercourse  ...
#
#    Lesser_Risk_Low_Confidence_Limit  Lesser_Risk_High_Confidence_Limit  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                            48.017                            74.9578
#
#    Sample_Size     Sex                Race  Grade SexualIdentity  \
# 0            9   Total  Hispanic or Latino   11th       Bisexual
# 1            0    Male               White  Total       Bisexual
# 2           49  Female               White   10th       Bisexual
#
#   SexOfSexualContacts                    GeoLocation LocationId
# 0               Total  (35.466220975, -79.159250463)       37.0
# 1               Total        (18.220833, -66.590149)       72.0
# 2               Total  (28.932040377, -81.928960539)       12.0
#
# [3 rows x 23 columns]

# %%
yrbss[(yrbss['LocationId'] == 37.0) & (yrbss['Sex'] == "Female") & (yrbss['Race'] == "White") & (yrbss['Grade'] == "11th")]
# Out:
#          YEAR LocationAbbr    LocationDesc DataSource  \
# 4372     2017           NC  North Carolina      YRBSS
# 5206     2017           NC  North Carolina      YRBSS
# 23116    2017           NC  North Carolina      YRBSS
# 25154    2017           NC  North Carolina      YRBSS
# 29943    2017           NC  North Carolina      YRBSS
# ...       ...          ...             ...        ...
# 7403331  2017           NC  North Carolina      YRBSS
# 7420696  2017           NC  North Carolina      YRBSS
# 7421385  2017           NC  North Carolina      YRBSS
# 7429037  2017           NC  North Carolina      YRBSS
# 7430151  2017           NC  North Carolina      YRBSS
#
#                                        Topic                   Subtopic  \
# 4372                        Sexual Behaviors           Sexual Behaviors
# 5206                     Other Health Topics                     Asthma
# 23116                      Dietary Behaviors                Soda or pop
# 25154                      Dietary Behaviors                  Breakfast
# 29943                            Tobacco Use          Other Tobacco Use
# ...                                      ...                        ...
# 7403331  Unintentional Injuries and Violence  Suicide-Related Behaviors
# 7420696                    Physical Activity          Physical Activity
# 7421385  Unintentional Injuries and Violence  Suicide-Related Behaviors
# 7429037           Alcohol and Other Drug Use             Other Drug Use
# 7430151  Unintentional Injuries and Violence  Suicide-Related Behaviors
#
#                                   ShortQuestionText  \
# 4372                        Ever sexual intercourse
# 5206                                         Asthma
# 23116                      Soda drinking >= 1 times
# 25154                              Breakfast eating
# 29943    Current daily electronic vapor product use
# ...                                             ...
# 7403331                           Attempted suicide
# 7420696                                  Concussion
# 7421385                           Attempted suicide
# 7429037                          Ever marijuana use
# 7430151                                Suicide plan
#
#                                      Greater_Risk_Question  \
# 4372                           Ever had sexual intercourse
# 5206     Were ever told by a doctor or nurse that they ...
# 23116    Drank a can, bottle, or glass of soda or pop o...
# 25154                                Did not eat breakfast
# 29943     Currently used an electronic vapor product daily
# ...                                                    ...
# 7403331                                  Attempted suicide
# 7420696  Had a concussion from playing a sport or being...
# 7421385                                  Attempted suicide
# 7429037                                Ever used marijuana
# 7430151   Made a plan about how they would attempt suicide
#
#                                                Description Data_Value_Symbol  \
# 4372                                                   NaN                 %
# 5206                                                   NaN                 %
# 23116    such as Coke, Pepsi, or Sprite, not counting d...                 %
# 25154                  during the 7 days before the survey                 %
# 29943    including e-cigarettes, e-cigars, e-pipes, vap...                 %
# ...                                                    ...               ...
# 7403331  one or more times during the 12 months before ...                 %
# 7420696             during the 12 months before the survey                 %
# 7421385  one or more times during the 12 months before ...                 %
# 7429037  also called grass, pot, or weed, one or more t...                 %
# 7430151             during the 12 months before the survey                 %
#
#          ... SubTopicID  QuestionCode  LocationId  StratID1  StratID2  \
# 4372     ...        C16           H59        37.0        S7       R15
# 5206     ...        C28           H87        37.0        S7       R15
# 23116    ...        C21       QNSODA1        37.0        S7       R15
# 25154    ...        C24           H78        37.0        S7       R15
# 29943    ...        C13      QNDAYEVP        37.0        S7       R15
# ...      ...        ...           ...         ...       ...       ...
# 7403331  ...        C11           H28        37.0        S7       R15
# 7420696  ...        C25           H84        37.0        S7       R15
# 7421385  ...        C11           H28        37.0        S7       R15
# 7429037  ...        C15           H46        37.0        S7       R15
# 7430151  ...        C11           H27        37.0        S7       R15
#
#          StratID3 StratID4  StratID5  StratificationType  StratID6
# 4372           G4       NC        I1               State       P29
# 5206           G4       NC       I22               State        P1
# 23116          G4       NC       I21               State        P1
# 25154          G4       NC        I1               State       P30
# 29943          G4       NC        I1               State        P1
# ...           ...      ...       ...                 ...       ...
# 7403331        G4       NC        I1               State       P31
# 7420696        G4       NC        I1               State       P31
# 7421385        G4       NC        I1               State       P29
# 7429037        G4       NC       I23               State        P1
# 7430151        G4       NC        I1               State       P32
#
# [891 rows x 40 columns]

# %%
loc37[['LocationDesc',  'Sex', 'Race',
       'Grade', 'SexualIdentity', 'GeoLocation',
       'TopicId', 'SubTopicID', 'QuestionCode', 'LocationId', 'StratID1',
       'StratID2', 'StratID3', 'StratID4', 'StratID5', 'StratificationType',
       'StratID6']]
# Out:
#            LocationDesc     Sex                              Race  Grade  \
# 0        North Carolina   Total                Hispanic or Latino   11th
# 132      North Carolina  Female         Black or African American  Total
# 153      North Carolina   Total  American Indian or Alaska Native    9th
# 187      North Carolina    Male                             Asian  Total
# 410      North Carolina    Male                             Total    9th
# ...                 ...     ...                               ...    ...
# 7461457  North Carolina    Male                Hispanic or Latino   11th
# 7461674  North Carolina   Total                Hispanic or Latino  Total
# 7461823  North Carolina  Female                     Multiple Race    9th
# 7461837  North Carolina    Male  American Indian or Alaska Native   12th
# 7461952  North Carolina    Male                             Asian   11th
#
#                     SexualIdentity                    GeoLocation TopicId  \
# 0                         Bisexual  (35.466220975, -79.159250463)     C05
# 132                          Total  (35.466220975, -79.159250463)     C07
# 153                          Total  (35.466220975, -79.159250463)     C07
# 187                          Total  (35.466220975, -79.159250463)     C04
# 410                          Total  (35.466220975, -79.159250463)     C04
# ...                            ...                            ...     ...
# 7461457                      Total  (35.466220975, -79.159250463)     C04
# 7461674                      Total  (35.466220975, -79.159250463)     C02
# 7461823  Gay, lesbian, or bisexual  (35.466220975, -79.159250463)     C03
# 7461837                      Total  (35.466220975, -79.159250463)     C07
# 7461952                   Not sure  (35.466220975, -79.159250463)     C05
#
#         SubTopicID QuestionCode  LocationId StratID1 StratID2 StratID3  \
# 0              C24     QNBK7DAY        37.0       S1      R13       G4
# 132            C27          H69        37.0       S7      R12       G1
# 153            C27          H69        37.0       S1      R10       G2
# 187            C16          H59        37.0       S8      R11       G1
# 410            C16          H59        37.0       S8       R1       G2
# ...            ...          ...         ...      ...      ...      ...
# 7461457        C16     QNBCNONE        37.0       S8      R13       G4
# 7461674        C12      QNFRCIG        37.0       S1      R13       G1
# 7461823        C14          H41        37.0       S7      R16       G2
# 7461837        C26        QNOWT        37.0       S8      R10       G5
# 7461952        C24     QNBK7DAY        37.0       S8      R11       G4
#
#         StratID4 StratID5 StratificationType StratID6
# 0             NC      I23              State       P1
# 132           NC       I1              State      P29
# 153           NC       I1              State      P32
# 187           NC       I1              State      P31
# 410           NC       I1              State      P29
# ...          ...      ...                ...      ...
# 7461457       NC       I1              State       P1
# 7461674       NC       I1              State       P1
# 7461823       NC      I24              State       P1
# 7461837       NC       I1              State      P31
# 7461952       NC      I25              State       P1
#
# [106920 rows x 17 columns]
