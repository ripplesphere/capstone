# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
yrbss = pd.read_csv('../data/yrbss_2017.csv')
print(yrbss.shape)
us_df = yrbss[yrbss['LocationAbbr'] == 'XX']
print(us_df.shape)
# Out:
# (7461960, 40)
# (163680, 40)

# %%
question_tots = []
for topic in us_df['Topic'].value_counts().items():
    topic_df = us_df[us_df['Topic'] == topic[0]]
    for subtopic in topic_df['Subtopic'].value_counts().items():
        subtopic_df = topic_df[topic_df['Subtopic'] == subtopic[0]]
        for risk_question in subtopic_df['Greater_Risk_Question'].value_counts().items():
            q_total = subtopic_df[(subtopic_df['Greater_Risk_Question'] == risk_question[0]) & 
                (subtopic_df['Sex'] == 'Female') &
                (subtopic_df['Grade'] == 'Total') &
                (subtopic_df['Race'] == 'Total') & (subtopic_df['SexualIdentity'] == 'Total') & 
                (subtopic_df['SexOfSexualContacts'] == 'Total')]
            q_val = q_total['Greater_Risk_Data_Value'].iloc[0]
            q_low = q_total['Greater_Risk_Low_Confidence_Limit'].iloc[0]
            q_high = q_total['Greater_Risk_High_Confidence_Limit'].iloc[0]
            question_tots.append([topic[0], subtopic[0], risk_question[0], q_low, q_val, q_high])

# %%
tots_df = pd.DataFrame(question_tots)

# %%
tots_df.to_csv('../data/female_tots_df.csv')

# %%
tots_df
# Out:
#                                            0                       1  \
# 0                          Dietary Behaviors       Water Consumption
# 1                          Dietary Behaviors                    Milk
# 2                          Dietary Behaviors  Fruit and fruit juices
# 3                          Dietary Behaviors           Sports Drinks
# 4                          Dietary Behaviors           Sports Drinks
# ..                                       ...                     ...
# 106                      Other Health Topics                  Asthma
# 107  Obesity, Overweight, and Weight Control          Weight Control
# 108  Obesity, Overweight, and Weight Control          Weight Control
# 109  Obesity, Overweight, and Weight Control  Obesity and Overweight
# 110  Obesity, Overweight, and Weight Control  Obesity and Overweight
#
#                                                      2        3        4  \
# ...

# %%
us_df[(us_df['Greater_Risk_Question'] == 'Played video or computer games or used a computer for 3 or more hours per day') & 
                (us_df['Grade'] == 'Total') & 
                (us_df['Race'] == 'Total') & (us_df['SexualIdentity'] == 'Total') & 
                (us_df['SexOfSexualContacts'] == 'Total')][['Greater_Risk_Data_Value', 'Greater_Risk_Low_Confidence_Limit', 'Greater_Risk_High_Confidence_Limit']]
# Out:
#          Greater_Risk_Data_Value  Greater_Risk_Low_Confidence_Limit  \
# 2129326                  42.9544                            40.4855
# 5107323                  43.0035                            41.1017
# 5694238                  43.0665                            40.3080
#
#          Greater_Risk_High_Confidence_Limit
# 2129326                             45.4590
# 5107323                             44.9262
# 5694238                             45.8688

# %%
us_df[(us_df['Grade'] == 'Total') & (us_df['Sex'] == 'Total') &
                (us_df['Race'] == 'Total') & (us_df['SexualIdentity'] == 'Total') & 
                (us_df['SexOfSexualContacts'] == 'Total')]
# Out:
#          YEAR LocationAbbr   LocationDesc DataSource  \
# 54954    2017           XX  United States      YRBSS
# 62509    2017           XX  United States      YRBSS
# 113634   2017           XX  United States      YRBSS
# 128278   2017           XX  United States      YRBSS
# 267372   2017           XX  United States      YRBSS
# ...       ...          ...            ...        ...
# 7224327  2017           XX  United States      YRBSS
# 7310961  2017           XX  United States      YRBSS
# 7390586  2017           XX  United States      YRBSS
# 7457594  2017           XX  United States      YRBSS
# 7460129  2017           XX  United States      YRBSS
#
#                                        Topic  \
# 54954                      Physical Activity
# 62509    Unintentional Injuries and Violence
# 113634                     Dietary Behaviors
# 128278                     Dietary Behaviors
# 267372   Unintentional Injuries and Violence
# ...                                      ...
# ...

# %%
us_df[(us_df['ShortQuestionText'] == 'Bullying at school') & 
      (us_df['Sex'] == 'Total') & (us_df['Grade'] == 'Total') &
     (us_df['SexualIdentity'] == 'Total') & (us_df['SexOfSexualContacts'] == 'Total')]
# Out:
#          YEAR LocationAbbr   LocationDesc DataSource  \
# 62509    2017           XX  United States      YRBSS
# 934917   2017           XX  United States      YRBSS
# 2335211  2017           XX  United States      YRBSS
# 2674010  2017           XX  United States      YRBSS
# 5740793  2017           XX  United States      YRBSS
# 6762058  2017           XX  United States      YRBSS
# 7177515  2017           XX  United States      YRBSS
# 7320494  2017           XX  United States      YRBSS
#
#                                        Topic  \
# 62509    Unintentional Injuries and Violence
# 934917   Unintentional Injuries and Violence
# 2335211  Unintentional Injuries and Violence
# 2674010  Unintentional Injuries and Violence
# 5740793  Unintentional Injuries and Violence
# 6762058  Unintentional Injuries and Violence
# 7177515  Unintentional Injuries and Violence
# 7320494  Unintentional Injuries and Violence
#
#                                       Subtopic   ShortQuestionText  \
# ...

# %%
114 / 14606
# Out:
# 0.007805011639052444

# %%
591 + 349 + 11910 + 1119
# Out:
# 13969

# %%
11910 / 13969
# Out:
# 0.8526021905648221
